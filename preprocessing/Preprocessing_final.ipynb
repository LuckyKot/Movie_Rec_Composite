# %%
import matplotlib.pyplot as plt
import matplotlib.lines as lines
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.metrics import root_mean_squared_error
import os, io
import torch

# %matplotlib inline


plt.rcParams.update({'figure.figsize': (12.0, 8.0)})
plt.rcParams.update({'font.size': 14})

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
ratings = pd.read_csv("/content/drive/MyDrive/CMPE256/256_project/Original_datasets/Netflix_Dataset_Rating.csv")
movies = pd.read_csv("/content/drive/MyDrive/CMPE256/256_project/movies_encoded.csv")

# %%
data = pd.merge(ratings, movies, on='Movie_ID')

# %%
del ratings, movies

# %%
data.drop(columns=['Name'], inplace=True)

# %%
data['runtimeMinutes']=data['runtimeMinutes'].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14583166 entries, 0 to 14583165
# Data columns (total 43 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   User_ID         int64
#  1   Rating          int64
#  2   Movie_ID        int64
#  3   Year            int64
#  4   isAdult         int64
#  5   runtimeMinutes  int64
#  6   movie           bool
#  7   short           bool
#  8   tvEpisode       bool
#  9   tvMiniSeries    bool
#  10  tvMovie         bool
#  11  tvSeries        bool
#  12  tvShort         bool
#  13  tvSpecial       bool
#  14  video           bool
#  15  Action          int64
#  16  Adult           int64
#  17  Adventure       int64
#  18  Animation       int64
#  19  Biography       int64
#  20  Comedy          int64
#  21  Crime           int64
#  22  Documentary     int64
#  23  Drama           int64
#  24  Family          int64
#  25  Fantasy         int64
#  26  Film-Noir       int64
#  27  Game-Show       int64
# ...

# %%
data.columns
# Out:
# Index(['User_ID', 'Rating', 'Movie_ID', 'Year', 'isAdult', 'runtimeMinutes',
#        'movie', 'short', 'tvEpisode', 'tvMiniSeries', 'tvMovie', 'tvSeries',
#        'tvShort', 'tvSpecial', 'video', 'Action', 'Adult', 'Adventure',
#        'Animation', 'Biography', 'Comedy', 'Crime', 'Documentary', 'Drama',
#        'Family', 'Fantasy', 'Film-Noir', 'Game-Show', 'History', 'Horror',
#        'Music', 'Musical', 'Mystery', 'News', 'Reality-TV', 'Romance',
#        'Sci-Fi', 'Short', 'Sport', 'Talk-Show', 'Thriller', 'War', 'Western'],
#       dtype='object')

# %%
data[['Action', 'Adult', 'Adventure', 'Animation', 'Biography', 'Comedy', 'Crime', 'Documentary', 'Drama','Family', 'Fantasy', 'Film-Noir', 'Game-Show', 'History', 'Horror', 'Music', 'Musical', 'Mystery', 'News', 'Reality-TV', 'Romance','Sci-Fi', 'Short', 'Sport', 'Talk-Show', 'Thriller', 'War', 'Western']] = data[['Action', 'Adult', 'Adventure', 'Animation', 'Biography', 'Comedy', 'Crime', 'Documentary', 'Drama','Family', 'Fantasy', 'Film-Noir', 'Game-Show', 'History', 'Horror', 'Music', 'Musical', 'Mystery', 'News', 'Reality-TV', 'Romance','Sci-Fi', 'Short', 'Sport', 'Talk-Show', 'Thriller', 'War', 'Western']].astype(bool)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14583166 entries, 0 to 14583165
# Data columns (total 43 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   User_ID         int64
#  1   Rating          int64
#  2   Movie_ID        int64
#  3   Year            int64
#  4   isAdult         int64
#  5   runtimeMinutes  int64
#  6   movie           bool
#  7   short           bool
#  8   tvEpisode       bool
#  9   tvMiniSeries    bool
#  10  tvMovie         bool
#  11  tvSeries        bool
#  12  tvShort         bool
#  13  tvSpecial       bool
#  14  video           bool
#  15  Action          bool
#  16  Adult           bool
#  17  Adventure       bool
#  18  Animation       bool
#  19  Biography       bool
#  20  Comedy          bool
#  21  Crime           bool
#  22  Documentary     bool
#  23  Drama           bool
#  24  Family          bool
#  25  Fantasy         bool
#  26  Film-Noir       bool
#  27  Game-Show       bool
#  28  History         bool
# ...

# %%
data[['isAdult','Adult']]
data['isAdult'].equals(data['Adult'])
# Out:
# False

# %%
data.drop(columns=['isAdult'], inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14583166 entries, 0 to 14583165
# Data columns (total 42 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   User_ID         int64
#  1   Rating          int64
#  2   Movie_ID        int64
#  3   Year            int64
#  4   runtimeMinutes  int64
#  5   movie           bool
#  6   short           bool
#  7   tvEpisode       bool
#  8   tvMiniSeries    bool
#  9   tvMovie         bool
#  10  tvSeries        bool
#  11  tvShort         bool
#  12  tvSpecial       bool
#  13  video           bool
#  14  Action          bool
#  15  Adult           bool
#  16  Adventure       bool
#  17  Animation       bool
#  18  Biography       bool
#  19  Comedy          bool
#  20  Crime           bool
#  21  Documentary     bool
#  22  Drama           bool
#  23  Family          bool
#  24  Fantasy         bool
#  25  Film-Noir       bool
#  26  Game-Show       bool
#  27  History         bool
#  28  Horror          bool
# ...

# %%
data.to_csv('/content/drive/MyDrive/CMPE256/256_project/train_final.csv', index=False)
